# %% [markdown]
# # Standardization
# - transform _continuous_ data to appear _normally distributed_

# %% [markdown]
# ## When to standardize
# - Model in _linear_ space. Eg.kNN, Linear regression, K-Means Clustering
# - Dataset features have high variance
# - Features are on different scales Eg.Predicting house prices using no. bedrooms and last sale price

# %%
import pandas as pd
wine = pd.read_csv('datasets/wine_types.csv')
wine.head()
# Out:
#    Type  Alcohol  Malic acid  ...   Hue  OD280/OD315 of diluted wines  Proline
# 0     1    14.23        1.71  ...  1.04                          3.92     1065
# 1     1    13.20        1.78  ...  1.05                          3.40     1050
# 2     1    13.16        2.36  ...  1.03                          3.17     1185
# 3     1    14.37        1.95  ...  0.86                          3.45     1480
# 4     1    13.24        2.59  ...  1.04                          2.93      735
#
# [5 rows x 14 columns]

# %%
X = wine.drop('Type',axis=1)
y = wine['Type']

# %% [markdown]
# # Without standardization

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

knn = KNeighborsClassifier()

# Fit the knn model to the training data
knn.fit(X_train, y_train)

# Score the model on the test data
print(knn.score(X_test,y_test))
# Out:
# 0.7777777777777778

# %% [markdown]
# # Log normalization
# - useful for features with high variance
# - applies logarithm transformation
# - Natural log using the constant e(==2.718)

# %%
# Checking for the candidate perfect for log normalization
wine.var()
# Out:
# Type                                0.600679
# Alcohol                             0.659062
# Malic acid                          1.248015
# Ash                                 0.075265
# Alcalinity of ash                  11.152686
# Magnesium                         203.989335
# Total phenols                       0.391690
# Flavanoids                          0.997719
# Nonflavanoid phenols                0.015489
# Proanthocyanins                     0.327595
# Color intensity                     5.374449
# Hue                                 0.052245
# OD280/OD315 of diluted wines        0.504086
# Proline                         99166.717355
# dtype: float64

# %% [markdown]
# **Proline** has extremely high variance.

# %%
import numpy as np

# Print out the variance of the Proline column
print(wine['Proline'].var())

# Apply the log normalization function to the Proline column
wine['Proline_log'] = np.log(wine['Proline'])

# Check the variance of the normalized Proline column
print(wine['Proline_log'].var())
# Out:
# 99166.71735542436
# 0.17231366191842012

# %% [markdown]
# # Scaling data for feature comparison
# - Center features around 0 and transform to variance of 1
# - Transforms to approx. normal distribution

# %%
# Checking the different scales in different features that could lead to bias in linear model
wine[['Ash','Alcalinity of ash','Magnesium']]
# Out:
#       Ash  Alcalinity of ash  Magnesium
# 0    2.43               15.6        127
# 1    2.14               11.2        100
# 2    2.67               18.6        101
# 3    2.50               16.8        113
# 4    2.87               21.0        118
# ..    ...                ...        ...
# 173  2.45               20.5         95
# 174  2.48               23.0        102
# 175  2.26               20.0        120
# 176  2.37               20.0        120
# 177  2.74               24.5         96
#
# [178 rows x 3 columns]

# %% [markdown]
# This proves that the `Ash`, `Alcalinity of ash`, and `Magnesium` columns in the wine dataset are all on different scales, so let's standardize them in a way that allows for use in a linear model.

# %%
# Import StandardScaler
from sklearn.preprocessing import StandardScaler

# Create the scaler
scaler = StandardScaler()

# Subset the DataFrame you want to scale 
wine_subset = wine[['Ash','Alcalinity of ash','Magnesium']]

# Apply the scaler to wine_subset
wine_subset_scaled = scaler.fit_transform(wine_subset)

# %%
wine_subset_scaled
# Out:
# array([[ 2.32052541e-01, -1.16959318e+00,  1.91390522e+00],
#        [-8.27996323e-01, -2.49084714e+00,  1.81450206e-02],
#        [-6.45229278e-01,  1.51829490e-03, -8.24415067e-01],
#        [ 8.90013905e-01,  1.35280076e+00,  8.83583612e-02],
#        [ 1.21899459e+00,  4.51945783e-01, -2.62708342e-01],
#        [-6.03747319e-02,  1.51660791e-01, -7.54201726e-01],
#        [ 1.29210141e+00,  1.20265826e+00, -1.92495001e-01],
#        [-6.03747319e-02,  1.51660791e-01, -5.43561704e-01],
#        [-6.08675869e-01, -2.98766697e-01,  8.60705108e-01],
#        [-7.91442914e-01,  4.51945783e-01,  1.58571702e-01],
#        [-4.99015641e-01,  1.51660791e-01, -1.38612179e+00],
#        [ 4.14819587e-01,  6.02088279e-01, -9.64841748e-01],
#        [ 4.92854954e-02,  6.02088279e-01, -5.43561704e-01],
#        [-2.38213228e-02,  6.02088279e-01,  9.30918449e-01],
#        [ 9.26567314e-01,  1.35280076e+00,  1.63305186e+00],
#        [ 4.14819587e-01,  7.52230776e-01,  8.60705108e-01],
#        [ 1.40176163e+00,  1.80322825e+00,  1.14155847e+00],
#        [-3.16248596e-01, -2.98766697e-01, -1.22281661e-01],
#        [-9.74209960e-01,  1.51660791e-01,  2.28785042e-01],
#        [-1.70034959e-01,  7.52230776e-01, -4.73348364e-01],
#        [ 4.92854954e-02,  1.51829490e-03, -7.54201726e-01],
#        [ 9.99674132e-01,  2.25365574e+00, -1.92495001e-01],
#        [ 1.21899459e+00,  1.65308575e+00, -1.22281661e-01],
#        [ 9.99674132e-01,  9.02373272e-01, -7.54201726e-01],
#        [ 4.92854954e-02,  4.51945783e-01, -8.24415067e-01],
#        [ 6.34140041e-01,  1.51660791e-01,  5.09638405e-01],
#        [ 7.80353678e-01,  7.52230776e-01,  4.39425064e-01],
#        [-6.03747319e-02, -2.98766697e-01,  4.39425064e-01],
#        [-2.43141777e-01,  7.52230776e-01, -6.83988386e-01],
#        [-3.89355414e-01,  9.02373272e-01, -8.24415067e-01],
#        [ 8.53460496e-01,  1.05251577e+00,  7.90491768e-01],
#        [-2.43141777e-01,  1.51829490e-03, -8.24415067e-01],
#        [ 1.18244118e+00,  1.50294326e+00,  3.69211724e-01],
#        [ 1.80384913e+00,  1.65308575e+00,  8.60705108e-01],
#        [-1.70034959e-01, -1.48624201e-01, -2.62708342e-01],
#        [-3.16248596e-01,  1.51829490e-03, -9.64841748e-01],
#        [ 4.14819587e-01,  1.51660791e-01, -6.13775045e-01],
#        [ 3.05159359e-01,  3.01803287e-01, -3.32921683e-01],
#        [ 4.14819587e-01,  1.05251577e+00,  1.58571702e-01],
#        [-3.89355414e-01,  1.51660791e-01,  1.42241183e+00],
#        [ 1.27320863e-02,  1.51660791e-01,  1.42241183e+00],
#        [ 1.36520822e+00,  1.50294326e+00, -2.62708342e-01]])

# %% [markdown]
# # With standardization

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

# Instantiate a StandardScaler
scaler = StandardScaler()

# Scale the training and test features
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Fit the k-nearest neighbors model to the training data
knn.fit(X_train_scaled, y_train)

# Score the model on the test data
print(knn.score(X_test_scaled, y_test))
# Out:
# 0.9333333333333333

# %% [markdown]
# The model has improved from 77.78% to 93.33%.
